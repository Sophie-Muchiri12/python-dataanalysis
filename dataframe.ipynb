# %%
person = {
    "first":"corey",
    "last":"schafer",
    "email":"corey@gmail.com"
}

# %%
person = {
    "first":["corey"],
    "last":["schafer"],
    "email":["corey@gmail.com"]
}

# %%
people = {
    "first":["corey","sophie", "cristian"],
    "last":["schafer","muthoni","rodriguez"],
    "email":["corey@gmail.com","muthoni@gmail.com","rodriguez@gmail.com"]
}

# %%
#what is a dataframe?
#A DataFrame is a 2-dimensional labeled data structure with Rows(indexed) and 
#Columns(named)

# %%
# creating a dataframe from the people object
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
#   (named columns)
#first	last	email 
# 0	corey	schafer	corey@gmail.com   (indexed rows)
# 1	sophie	muthoni	muthoni@gmail.com
# 2	cristian	rodriguez	rodriguez@gmail.com

# 
# 
# 
# 
#

# %%
# accessing a specific column in dataframe
df['email']
# Out:
# 0        corey@gmail.com
# 1      muthoni@gmail.com
# 2    rodriguez@gmail.com
# Name: email, dtype: str

# %%
type(df['email'])
# Out:
# pandas.Series

# %%
#SERIES:
#rows of a single column
#email series:

# 0        corey@gmail.com
# 1      muthoni@gmail.com
# 2    rodriguez@gmail.com
# Name: email, dtype: str

# accessing series as a key
# df['email']

# using dot notation
# df.email
df.email
# Out:
# 0        corey@gmail.com
# 1      muthoni@gmail.com
# 2    rodriguez@gmail.com
# Name: email, dtype: str

# %%
#accessing multiple colums
df[['last','email']]

#this is nolonger a series but filtered down dataframe
# Out:
#         last                email
# 0    schafer      corey@gmail.com
# 1    muthoni    muthoni@gmail.com
# 2  rodriguez  rodriguez@gmail.com

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.iloc[0]
df.iloc[[0,1]]
df.iloc[[0,1],2]
# Out:
# 0      corey@gmail.com
# 1    muthoni@gmail.com
# Name: email, dtype: str

# %%
#loc (labels)
#the default indexes are our labels:
# label
# 0	schafer	corey@gmail.com
# 1	muthoni	muthoni@gmail.com
# 2	rodriguez	rodriguez@gmail.com
df.loc[0]
# Out:
# first              corey
# last             schafer
# email    corey@gmail.com
# Name: 0, dtype: str

# %%
df.loc[[0,1],'email']
# Out:
# 0      corey@gmail.com
# 1    muthoni@gmail.com
# Name: email, dtype: str

# %%
df.loc[[0,1],['email','last']]
# Out:
#                email     last
# 0    corey@gmail.com  schafer
# 1  muthoni@gmail.com  muthoni

# %%
df.apply(lambda x:x.min())
# Out:
# first              corey
# last             muthoni
# email    corey@gmail.com
# dtype: str

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# dtype: object

# %%
df.size
# Out:
# 9

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
df.T
# Out:
#                      0                  1                    2
# first            corey             sophie             cristian
# last           schafer            muthoni            rodriguez
# email  corey@gmail.com  muthoni@gmail.com  rodriguez@gmail.com

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   3 non-null      str
#  1   last    3 non-null      str
#  2   email   3 non-null      str
# dtypes: str(3)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#         first     last            email
# count       3        3                3
# unique      3        3                3
# top     corey  schafer  corey@gmail.com
# freq        1        1                1

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
df.sort_values(by='last')
# Out:
#       first       last                email
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com
# 0     corey    schafer      corey@gmail.com

# %%
df['last']
# Out:
# 0      schafer
# 1      muthoni
# 2    rodriguez
# Name: last, dtype: str

# %%
df.loc[0,'first']
# Out:
# 'corey'

# %%
df.loc[0]
# Out:
# first              corey
# last             schafer
# email    corey@gmail.com
# Name: 0, dtype: str

# %%
df.iloc[0]
# Out:
# first              corey
# last             schafer
# email    corey@gmail.com
# Name: 0, dtype: str

# %%
df.iloc[0,0]
# Out:
# 'corey'

# %%
df.iloc[0,2]
# Out:
# 'corey@gmail.com'

# %%
df.rename(columns={
    'first':'firstname'
})
# Out:
#   firstname       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
df.isnull()
# Out:
#    first   last  email
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False

# %%
df.notnull()
# Out:
#    first  last  email
# 0   True  True   True
# 1   True  True   True
# 2   True  True   True

# %%
df['age']= [24,None,34]

# %%
df
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 1    sophie    muthoni    muthoni@gmail.com   NaN
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df.notnull()
# Out:
#    first  last  email    age
# 0   True  True   True   True
# 1   True  True   True  False
# 2   True  True   True   True

# %%
df.fillna(0)
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 1    sophie    muthoni    muthoni@gmail.com   0.0
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df.fillna(1)
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 1    sophie    muthoni    muthoni@gmail.com   1.0
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df.loc[[0,2]]
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df.loc[0:2]
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 1    sophie    muthoni    muthoni@gmail.com   NaN
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 1    sophie    muthoni    muthoni@gmail.com   NaN
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df.dropna()
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 1    sophie    muthoni    muthoni@gmail.com   NaN
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       first       last                email   age
# 0     corey    schafer      corey@gmail.com  24.0
# 2  cristian  rodriguez  rodriguez@gmail.com  34.0

# %%
df['age'].astype(int)
# Out:
# 0    24
# 2    34
# Name: age, dtype: int64

# %%
df['age'].dropna()
# Out:
# 0    24.0
# 2    34.0
# Name: age, dtype: float64
