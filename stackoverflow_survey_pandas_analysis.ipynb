# %%
import pandas as pd

# %%
df = pd.read_csv('stack-overflow-data25/survey_results_public.csv', low_memory=False)
# df = pd.read_csv('stack-overflow-data25/survey_results_public.csv', low_memory=False, index_col='ResponseId')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
df.shape
# Out:
# (49191, 172)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49191 entries, 0 to 49190
# Columns: 172 entries, ResponseId to JobSat
# dtypes: float64(52), int64(1), str(119)
# memory usage: 64.6 MB

# %%
pd.set_option('display.max_columns',172)
pd.set_option('display.max_rows',172)

# %%
schema_df = pd.read_csv('stack-overflow-data25/survey_results_schema.csv', index_col='qname')

# %%
schema_df
# Out:
#                          qid  \
# qname
# TechEndorse_1          QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechOppose_1           QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_16          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# JobSatPoints_1         QID27
# JobSatPoints_2         QID27
# JobSatPoints_16        QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# ...

# %%
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
df.head(10)
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
# 5           6  I am a developer by profession  45-54 years old
# 6           7  I am a developer by profession  25-34 years old
# 7           8  I am a developer by profession  35-44 years old
# 8           9  I am a developer by profession  25-34 years old
# 9          10  I am a developer by profession  25-34 years old
#
#                                              EdLevel  \
# 0    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1                Associate degree (A.A., A.S., etc.)
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df.shape
# Out:
# (49191, 172)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
df['MainBranch']
# Out:
# 0                           I am a developer by profession
# 1                           I am a developer by profession
# 2                           I am a developer by profession
# 3                           I am a developer by profession
# 4                           I am a developer by profession
#                                ...
# 49186                          I code primarily as a hobby
# 49187                       I am a developer by profession
# 49188                       I am a developer by profession
# 49189                       I am a developer by profession
# 49190    I am not primarily a developer, but I write co...
# Name: MainBranch, Length: 49191, dtype: str

# %%
df['MainBranch'].value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                                37467
# I am not primarily a developer, but I write code sometimes as part of my work/studies          4894
# I am learning to code                                                                          2585
# I code primarily as a hobby                                                                    1924
# I used to be a developer by profession, but no longer am                                       1325
# I work with developers or my work supports developers but am not a developer by profession      996
# Name: count, dtype: int64

# %%
# df.loc['ResponseId']

# %%
# df.loc[0, 'EdLevel']

# %%
# df.loc[[0,1,2], 'EdLevel']

# %%
#slicing dont wrap inner brackets
#slicing using default indexes
df.loc[0:2]
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
# 2                                None of the above     10.0
#
# ...

# %%
#slicing using column names
df.loc[0:2, 'MainBranch':'EdLevel']
# Out:
#                        MainBranch              Age  \
# 0  I am a developer by profession  25-34 years old
# 1  I am a developer by profession  25-34 years old
# 2  I am a developer by profession  35-44 years old
#
#                                            EdLevel
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)

# %%
#slicing is inclusive of the end value unlike normal
#python slicing

# %%
schema_df
# Out:
#                          qid  \
# qname
# TechEndorse_1          QID18
# TechEndorse_2          QID18
# TechEndorse_3          QID18
# TechEndorse_4          QID18
# TechEndorse_5          QID18
# TechEndorse_6          QID18
# TechEndorse_7          QID18
# TechEndorse_8          QID18
# TechEndorse_9          QID18
# TechEndorse_13         QID18
# TechEndorse_13_TEXT    QID18
# TechOppose_1           QID19
# TechOppose_2           QID19
# TechOppose_3           QID19
# TechOppose_5           QID19
# TechOppose_7           QID19
# TechOppose_9           QID19
# TechOppose_11          QID19
# TechOppose_13          QID19
# TechOppose_16          QID19
# TechOppose_15          QID19
# TechOppose_15_TEXT     QID19
# JobSatPoints_1         QID27
# JobSatPoints_2         QID27
# JobSatPoints_16        QID27
# JobSatPoints_3         QID27
# JobSatPoints_4         QID27
# JobSatPoints_5         QID27
# JobSatPoints_6         QID27
# JobSatPoints_7         QID27
# ...

# %%
schema_df.loc['AIAgentExtWrite']
# Out:
# qid                                                    QID104
# question    Was the out-of-the-box agents, copilots or ass...
# type                                                       TE
# sub                                                       NaN
# sq_id                                                     NaN
# Name: AIAgentExtWrite, dtype: object

# %%
schema_df.loc['AIAgentExtWrite','question'] #to see the full question pass the column name
# Out:
# 'Was the out-of-the-box agents, copilots or assistants you used in the past year not listed above?  Please write them below separated by a comma and space if there are more than one.'

# %%
#sorting alphabetically
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
#permanently sorting or sorting by default
schema_df.sort_index(inplace=True)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
pd.set_option('display.max_columns', None)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
df.loc[:,'ConvertedCompYearly']
# Out:
# 0         61256.0
# 1        104413.0
# 2         53061.0
# 3         36197.0
# 4         60000.0
#            ...
# 49186         NaN
# 49187         NaN
# 49188         NaN
# 49189         NaN
# 49190         NaN
# Name: ConvertedCompYearly, Length: 49191, dtype: float64

# %%
high_salary = (df['ConvertedCompYearly'] > 50000)

# %%
high_salary
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 49186    False
# 49187    False
# 49188    False
# 49189    False
# 49190    False
# Name: ConvertedCompYearly, Length: 49191, dtype: bool

# %%
df.loc[high_salary]
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 4               5                     I am a developer by profession
# 5               6                     I am a developer by profession
# ...           ...                                                ...
# 49083       49084  I am not primarily a developer, but I write co...
# 49084       49085  I am not primarily a developer, but I write co...
# 49088       49089  I work with developers or my work supports dev...
# 49106       49107                     I am a developer by profession
# 49121       49122                     I am a developer by profession
#
#                    Age                                          EdLevel  \
# ...

# %%
df.loc[high_salary, ['Country','Employment','CompTotal']]
# Out:
#                         Country  \
# 0                       Ukraine
# 1                   Netherlands
# 2                       Ukraine
# 4                       Ukraine
# 5                       Ukraine
# ...                         ...
# 49083  United States of America
# 49084  United States of America
# 49088  United States of America
# 49106              South Africa
# 49121                    France
#
#                                               Employment  CompTotal
# 0                                               Employed    52800.0
# 1                                               Employed    90000.0
# 2      Independent contractor, freelancer, or self-em...  2214000.0
# 4      Independent contractor, freelancer, or self-em...    60000.0
# 5      Independent contractor, freelancer, or self-em...   120000.0
# ...                                                  ...        ...
# 49083                                           Employed   188000.0
# ...

# %%
#filtering with multiple values
countries = ['United states', 'India', 'United Kingdom', 'Germany','Canada']
filt_country = df['Country'].isin(countries)

# %%
df.loc[filt_country, 'Country']
# Out:
# 13         India
# 15         India
# 18       Germany
# 35       Germany
# 46         India
#           ...
# 49154      India
# 49155      India
# 49175    Germany
# 49178    Germany
# 49180     Canada
# Name: Country, Length: 6877, dtype: str

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0                         Bash/Shell (all shells);Dart;SQL
# 1                                                     Java
# 2                      Dart;HTML/CSS;JavaScript;TypeScript
# 3                                          Java;Kotlin;SQL
# 4        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
#                                ...
# 49186                                                  NaN
# 49187                                                  NaN
# 49188                                                  NaN
# 49189                                                  NaN
# 49190                                                  NaN
# Name: LanguageHaveWorkedWith, Length: 49191, dtype: str

# %%
#using string method
filt_lang = df['LanguageHaveWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt_lang,'LanguageHaveWorkedWith']
# Out:
# 4        C;C#;C++;Delphi;HTML/CSS;Java;JavaScript;Lua;P...
# 7        Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 8                                        Java;Python;Scala
# 15       Ada;Assembly;C;C#;C++;COBOL;Dart;Delphi;Elixir...
# 17                          HTML/CSS;JavaScript;Python;SQL
#                                ...
# 49143            HTML/CSS;JavaScript;Python;SQL;TypeScript
# 49145    Assembly;Bash/Shell (all shells);C;C++;Python;...
# 49175    Bash/Shell (all shells);C#;C++;GDScript;HTML/C...
# 49176    Bash/Shell (all shells);HTML/CSS;JavaScript;Py...
# 49177    Bash/Shell (all shells);HTML/CSS;Lisp;PowerShe...
# Name: LanguageHaveWorkedWith, Length: 18466, dtype: str

# %%
#true and false value provides a mask of the data returned

# %%
#renaming comptotal to salary
df.rename(columns={
    'CompTotal':'SalaryUSD'
},inplace=True)

# %%
df['SalaryUSD']
# Out:
# 0          52800.0
# 1          90000.0
# 2        2214000.0
# 3          31200.0
# 4          60000.0
#            ...
# 49186          NaN
# 49187          NaN
# 49188      80000.0
# 49189          NaN
# 49190          NaN
# Name: SalaryUSD, Length: 49191, dtype: float64

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df['PurchaseInfluence'].map({
    'Yes': True,
    'No' : False,
})
# Out:
# 0          NaN
# 1        False
# 2        False
# 3        False
# 4          NaN
#          ...
# 49186      NaN
# 49187      NaN
# 49188      NaN
# 49189      NaN
# 49190      NaN
# Name: PurchaseInfluence, Length: 49191, dtype: object

# %%
df['PurchaseInfluence'] = df['PurchaseInfluence'].map({
    'Yes': True,
    'No' : False,
})

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df['Country']
# Out:
# 0            Ukraine
# 1        Netherlands
# 2            Ukraine
# 3            Ukraine
# 4            Ukraine
#             ...
# 49186            NaN
# 49187            NaN
# 49188          Italy
# 49189            NaN
# 49190            NaN
# Name: Country, Length: 49191, dtype: str

# %%
df.sort_values(by='Country', inplace=True)

# %%
df['Country'].head(100)
# Out:
# 6835             Afghanistan
# 6009             Afghanistan
# 15707            Afghanistan
# 7076             Afghanistan
# 19815            Afghanistan
# 44796            Afghanistan
# 45924            Afghanistan
# 27098            Afghanistan
# 40306            Afghanistan
# 40966            Afghanistan
# 38608            Afghanistan
# 7924             Afghanistan
# 7166             Afghanistan
# 37730                Albania
# 14757                Albania
# 36996                Albania
# 48949                Albania
# 28587                Albania
# 2022                 Albania
# 35183                Albania
# 16238                Albania
# 33939                Albania
# 45420                Albania
# 3887                 Albania
# 44878                Albania
# 44945                Albania
# 35933                Albania
# 22399                Albania
# 8775                 Albania
# 11873                Albania
# 41906                Albania
# 27801                Albania
# ...

# %%
df.columns = df.columns.str.strip()

# %%
df[['Country','ConvertedCompYearly']].head(100)
# Out:
#                    Country  ConvertedCompYearly
# 6835           Afghanistan                  NaN
# 6009           Afghanistan                986.0
# 15707          Afghanistan                  NaN
# 7076           Afghanistan               8450.0
# 19815          Afghanistan                  NaN
# 44796          Afghanistan                  NaN
# 45924          Afghanistan               7042.0
# 27098          Afghanistan                  NaN
# 40306          Afghanistan               9858.0
# 40966          Afghanistan              65000.0
# 38608          Afghanistan               1000.0
# 7924           Afghanistan                282.0
# 7166           Afghanistan               5200.0
# 37730              Albania              67779.0
# 14757              Albania              34804.0
# 36996              Albania                  NaN
# 48949              Albania              17402.0
# 28587              Albania             118286.0
# 2022               Albania             139218.0
# ...

# %%
[col for col in df.columns if 'comp' in col.lower()]
# Out:
# ['AIComplex', 'ConvertedCompYearly']

# %%
#sorting countries in ascending order then salary in descending order
df.sort_values(by=['Country','ConvertedCompYearly'], ascending=[True,False], inplace=True)

# %%
df[['Country','ConvertedCompYearly']].head(10)
# Out:
#            Country  ConvertedCompYearly
# 40966  Afghanistan              65000.0
# 40306  Afghanistan               9858.0
# 7076   Afghanistan               8450.0
# 45924  Afghanistan               7042.0
# 7166   Afghanistan               5200.0
# 38608  Afghanistan               1000.0
# 6009   Afghanistan                986.0
# 7924   Afghanistan                282.0
# 6835   Afghanistan                  NaN
# 15707  Afghanistan                  NaN

# %%
#largest and smallest values
df['ConvertedCompYearly'].nlargest(10) #10 largest
# Out:
# 34267    50000000.0
# 28700    33552715.0
# 43143    18387548.0
# 35353    15430267.0
# 45971    13921760.0
# 48428    10000000.0
# 24900     9531653.0
# 10025     9000000.0
# 37352     6890299.0
# 30728     6371285.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df.nlargest(10,'ConvertedCompYearly')
# Out:
#        ResponseId                                         MainBranch  \
# 34267       34268                        I code primarily as a hobby
# 28700       28701                     I am a developer by profession
# 43143       43144                        I code primarily as a hobby
# 35353       35354                     I am a developer by profession
# 45971       45972  I work with developers or my work supports dev...
# 48428       48429                        I code primarily as a hobby
# 24900       24901                     I am a developer by profession
# 10025       10026                     I am a developer by profession
# 37352       37353                     I am a developer by profession
# 30728       30729                     I am a developer by profession
#
#                    Age                                          EdLevel  \
# 34267  55-64 years old              Associate degree (A.A., A.S., etc.)
# ...

# %%
df['ConvertedCompYearly'].nsmallest(10) #10 smallest
# Out:
# 34865    1.0
# 41682    1.0
# 34567    1.0
# 27892    1.0
# 28177    1.0
# 42078    1.0
# 16489    1.0
# 4580     1.0
# 21034    1.0
# 26961    1.0
# Name: ConvertedCompYearly, dtype: float64

# %%
 #aggregration taking multiple data into a single result
df['ConvertedCompYearly'].head(15)
# Out:
# 40966     65000.0
# 40306      9858.0
# 7076       8450.0
# 45924      7042.0
# 7166       5200.0
# 38608      1000.0
# 6009        986.0
# 7924        282.0
# 6835          NaN
# 15707         NaN
# 19815         NaN
# 44796         NaN
# 27098         NaN
# 2022     139218.0
# 28587    118286.0
# Name: ConvertedCompYearly, dtype: float64

# %%
df['ConvertedCompYearly'].sort_index()
# Out:
# 0         61256.0
# 1        104413.0
# 2         53061.0
# 3         36197.0
# 4         60000.0
#            ...
# 49186         NaN
# 49187         NaN
# 49188         NaN
# 49189         NaN
# 49190         NaN
# Name: ConvertedCompYearly, Length: 49191, dtype: float64

# %%
df['ConvertedCompYearly']
# Out:
# 40966    65000.0
# 40306     9858.0
# 7076      8450.0
# 45924     7042.0
# 7166      5200.0
#           ...
# 49185        NaN
# 49186        NaN
# 49187        NaN
# 49189        NaN
# 49190        NaN
# Name: ConvertedCompYearly, Length: 49191, dtype: float64

# %%
df['ConvertedCompYearly'] = df['ConvertedCompYearly'].sort_index()

# %%
df['ConvertedCompYearly']
# Out:
# 40966    65000.0
# 40306     9858.0
# 7076      8450.0
# 45924     7042.0
# 7166      5200.0
#           ...
# 49185        NaN
# 49186        NaN
# 49187        NaN
# 49189        NaN
# 49190        NaN
# Name: ConvertedCompYearly, Length: 49191, dtype: float64

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 40966       40967                     I am a developer by profession
# 40306       40307                     I am a developer by profession
# 7076         7077  I am not primarily a developer, but I write co...
# 45924       45925                     I am a developer by profession
# 7166         7167                     I am a developer by profession
# ...           ...                                                ...
# 49185       49186                     I am a developer by profession
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df = df.sort_index()

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2                     I am a developer by profession
# 2               3                     I am a developer by profession
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 49186       49187                        I code primarily as a hobby
# 49187       49188                     I am a developer by profession
# 49188       49189                     I am a developer by profession
# 49189       49190                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df['ConvertedCompYearly'].median()
# Out:
# np.float64(75320.0)

# %%
df.median(numeric_only=True)
# Out:
# ResponseId              24596.0
# WorkExp                    10.0
# YearsCode                  14.0
# TechEndorse_1               9.0
# TechEndorse_2               4.0
# TechEndorse_3               4.0
# TechEndorse_4               6.0
# TechEndorse_5               4.0
# TechEndorse_6               5.0
# TechEndorse_7               7.0
# TechEndorse_8               4.0
# TechEndorse_9               4.0
# TechEndorse_13             10.0
# TechOppose_1                9.0
# TechOppose_2                4.0
# TechOppose_3                6.0
# TechOppose_5                5.0
# TechOppose_7                4.0
# TechOppose_9                3.0
# TechOppose_11               4.0
# TechOppose_13               5.0
# TechOppose_16               6.0
# TechOppose_15              10.0
# JobSatPoints_1              6.0
# JobSatPoints_2              4.0
# JobSatPoints_3              7.0
# JobSatPoints_4             10.0
# JobSatPoints_5             10.0
# JobSatPoints_6              8.0
# ...

# %%
df.describe()
# Out:
#          ResponseId       WorkExp     YearsCode  TechEndorse_1  TechEndorse_2  \
# count  49191.000000  42893.000000  43042.000000   35975.000000   35975.000000
# mean   24596.000000     13.367403     16.570861       7.867352       4.104211
# std    14200.362883     10.800117     11.787610       2.397432       2.275821
# min        1.000000      1.000000      1.000000       1.000000       1.000000
# 25%    12298.500000      5.000000      8.000000       7.000000       2.000000
# 50%    24596.000000     10.000000     14.000000       9.000000       4.000000
# 75%    36893.500000     20.000000     24.000000       9.000000       6.000000
# max    49191.000000    100.000000    100.000000      14.000000      14.000000
#
#        TechEndorse_3  TechEndorse_4  TechEndorse_5  TechEndorse_6  \
# count   35975.000000   35975.000000   35975.000000   35975.000000
# mean        4.110271       5.678193       4.119388       5.225990
# std         2.329536       2.398084       2.437945       2.801045
# ...

# %%
#what are outliers and how they affect mean
#the count value is the number of NaN rows
df['Employment'].value_counts()
# Out:
# Employment
# Employed                                                33750
# Independent contractor, freelancer, or self-employed     6708
# Student                                                  4428
# Not employed                                             2227
# Retired                                                   708
# I prefer not to say                                       518
# Name: count, dtype: int64

# %%
[col for col in df.columns if 'Social' in col.lower()]
# Out:
# []

# %%
[col for col in df.columns if 'Social' in col.lower()]
# Out:
# []

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
schema_df.loc['AIAgentChallenges']
# Out:
# qid                                                     QID88
# question    To what extent do you agree with the following...
# type                                                   Matrix
# sub                                                       NaN
# sq_id                                                     NaN
# Name: AIAgentChallenges, dtype: object

# %%
#setting percentage values
df['Employment'].value_counts(normalize=True)
# Out:
# Employment
# Employed                                                0.698194
# Independent contractor, freelancer, or self-employed    0.138770
# Student                                                 0.091603
# Not employed                                            0.046070
# Retired                                                 0.014647
# I prefer not to say                                     0.010716
# Name: proportion, dtype: float64

# %%
#grouping data
#groupby - involves some combination of splitting the object appying the function and c
#combining the result

#lets see the result by country
df['Country'].value_counts()

df['Country'] = df['Country'].str.strip()

# %%
df['Country'] = df['Country'].str.strip()

# %%
#split the object
country_grp = df.groupby(['Country'])

# %%
# DataFrameGroupBy - contains a bunch of groups
country_grp

# %%
country_grp.groups.keys()
# Out:
# /tmp/ipykernel_23428/3729241689.py:1: Pandas4Warning: In a future version, the keys of `groups` will be a tuple with a single element, e.g. (Country,) , instead of a scalar, e.g. Country, when grouping by a list with a single element. Use ``df.groupby(by='a').groups`` instead of ``df.groupby(by=['a']).groups`` to avoid this warning
#   country_grp.groups.keys()
# ...

# %%
#grab a certain group by name
country_grp.get_group('United States of America')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 2
#       1 #grab a certain group by name
# ----> 2 country_grp.get_group('United States of America')
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:885, in BaseGroupBy.get_group(self, name)
#     883         name = name[0]
#     884     else:
# --> 885         raise KeyError(name)
#     887 inds = self._get_index(name)
#     888 if not len(inds):
#
# KeyError: 'United States of America'

# %%
for key in country_grp.groups.keys():
    if 'United States' in key:
        print(repr(key))
# Out:
# 'United States of America'
# /tmp/ipykernel_23428/1507019728.py:1: Pandas4Warning: In a future version, the keys of `groups` will be a tuple with a single element, e.g. (Country,) , instead of a scalar, e.g. Country, when grouping by a list with a single element. Use ``df.groupby(by='a').groups`` instead of ``df.groupby(by=['a']).groups`` to avoid this warning
#   for key in country_grp.groups.keys():

# %%
for key in country_grp.groups.keys():
    print(type(key), repr(key))
    break
# Out:
# <class 'str'> 'Afghanistan'
# /tmp/ipykernel_23428/3101584944.py:1: Pandas4Warning: In a future version, the keys of `groups` will be a tuple with a single element, e.g. (Country,) , instead of a scalar, e.g. Country, when grouping by a list with a single element. Use ``df.groupby(by='a').groups`` instead of ``df.groupby(by=['a']).groups`` to avoid this warning
#   for key in country_grp.groups.keys():

# %%
df['Country'] = df['Country'].str.strip()
country_grp = df.groupby('Country')

# %%
#grab a certain group by name
country_grp.get_group('United States of America')
# Out:
#        ResponseId                                         MainBranch  \
# 21             22  I am not primarily a developer, but I write co...
# 22             23                     I am a developer by profession
# 29             30                     I am a developer by profession
# 31             32                     I am a developer by profession
# 33             34                     I am a developer by profession
# ...           ...                                                ...
# 49125       49126  I work with developers or my work supports dev...
# 49127       49128                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49157       49158                     I am a developer by profession
# 49177       49178                              I am learning to code
#
#                    Age                                            EdLevel  \
# ...

# %%
# the filt variable takes the series country and only picks the value equal to
# United States of America
filt = df['Country'] == 'United States of America'
df.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 21             22  I am not primarily a developer, but I write co...
# 22             23                     I am a developer by profession
# 29             30                     I am a developer by profession
# 31             32                     I am a developer by profession
# 33             34                     I am a developer by profession
# ...           ...                                                ...
# 49125       49126  I work with developers or my work supports dev...
# 49127       49128                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49157       49158                     I am a developer by profession
# 49177       49178                              I am learning to code
#
#                    Age                                            EdLevel  \
# ...

# %%
df.loc[0]
# Out:
# ResponseId                                                                                  1
# MainBranch                                                     I am a developer by profession
# Age                                                                           25-34 years old
# EdLevel                                       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# Employment                                                                           Employed
# EmploymentAddl                                Caring for dependents (children, elderly, etc.)
# WorkExp                                                                                   8.0
# LearnCodeChoose                             Yes, I am not new to coding but am learning ne...
# LearnCode                                   Online Courses or Certification (includes all ...
# LearnCodeAI                                 Yes, I learned how to use AI-enabled tools for...
# ...

# %%
 #maybe we want to see status of employment
df.loc[filt]['Employment'].value_counts()
# Out:
# Employment
# Employed                                                5413
# Independent contractor, freelancer, or self-employed     723
# Not employed                                             406
# Student                                                  405
# Retired                                                  214
# I prefer not to say                                       72
# Name: count, dtype: int64

# %%
df.loc[0,'Country']
# Out:
# 'Ukraine'

# %%
df.loc[[0,1]]
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
#
#                                            EdLevel Employment  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)   Employed
# 1              Associate degree (A.A., A.S., etc.)   Employed
#
#                                     EmploymentAddl  WorkExp  \
# 0  Caring for dependents (children, elderly, etc.)      8.0
# 1                                              NaN      2.0
#
#                                      LearnCodeChoose  \
# 0  Yes, I am not new to coding but am learning ne...
# 1  Yes, I am not new to coding but am learning ne...
#
#                                            LearnCode  \
# 0  Online Courses or Certification (includes all ...
# 1  Online Courses or Certification (includes all ...
#
#                                          LearnCodeAI  \
# ...

# %%
# .loc single operation
df.loc[filt]
# Out:
#        ResponseId                                         MainBranch  \
# 21             22  I am not primarily a developer, but I write co...
# 22             23                     I am a developer by profession
# 29             30                     I am a developer by profession
# 31             32                     I am a developer by profession
# 33             34                     I am a developer by profession
# ...           ...                                                ...
# 49125       49126  I work with developers or my work supports dev...
# 49127       49128                     I am a developer by profession
# 49145       49146                     I am a developer by profession
# 49157       49158                     I am a developer by profession
# 49177       49178                              I am learning to code
#
#                    Age                                            EdLevel  \
# ...

# %%
df.loc[filt,'Employment'].value_counts()
# Out:
# Employment
# Employed                                                5413
# Independent contractor, freelancer, or self-employed     723
# Not employed                                             406
# Student                                                  405
# Retired                                                  214
# I prefer not to say                                       72
# Name: count, dtype: int64

# %%
country_grp['Employment'].value_counts().head(50) #returns a series
# Out:
# Country              Employment
# Afghanistan          Employed                                                  7
#                      Student                                                   3
#                      Independent contractor, freelancer, or self-employed      2
#                      Not employed                                              1
# Albania              Employed                                                 13
#                      Independent contractor, freelancer, or self-employed      7
#                      Student                                                   1
#                      I prefer not to say                                       1
# Algeria              Student                                                  17
#                      Independent contractor, freelancer, or self-employed     16
#                      Employed                                                 12
# ...

# %%
country_grp['Employment'].value_counts().loc['India']
# Out:
# Employment
# Employed                                                1698
# Student                                                  453
# Independent contractor, freelancer, or self-employed     238
# Not employed                                             126
# I prefer not to say                                       25
# Retired                                                    7
# Name: count, dtype: int64

# %%
[col for col in df.columns if 'Social' in col.lower()]
# Out:
# []

# %%
#percentage result
country_grp['Employment'].value_counts(normalize=True).loc['India']
# Out:
# Employment
# Employed                                                0.666667
# Student                                                 0.177856
# Independent contractor, freelancer, or self-employed    0.093443
# Not employed                                            0.049470
# I prefer not to say                                     0.009815
# Retired                                                 0.002748
# Name: proportion, dtype: float64

# %%
# median of salary column
[col for col in df.columns if 'Converted' in col.lower()]
# Out:
# []

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
schema_df.loc['CompTotal']
# Out:
# qid                                                     QID22
# question    What is your current total <b>annual</b> compe...
# type                                                       TE
# sub                                                       NaN
# sq_id                                                     NaN
# Name: CompTotal, dtype: object

# %%
country_grp['ConvertedCompYearly'].median()
# Out:
# Country
# Afghanistan                               6121.0
# Albania                                  26269.0
# Algeria                                   6472.0
# Andorra                                 200125.5
# Angola                                    9578.0
#                                           ...
# Venezuela, Bolivarian Republic of...      9000.0
# Viet Nam                                  7642.0
# Yemen                                     5545.5
# Zambia                                    1966.5
# Zimbabwe                                 17500.0
# Name: ConvertedCompYearly, Length: 177, dtype: float64

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
country_grp.groups
# Out:
# {'Afghanistan': [6009, 6835, 7076, 7166, 7924, 15707, 19815, 27098, 38608, 40306, 40966, 44796, 45924], 'Albania': [2022, 3184, 3887, 8775, 11873, 14757, 16238, 16849, 22399, 25303, 27801, 28587, 33939, 35183, 35933, 36996, 37730, 41906, 44878, 44945, 45420, 48949], 'Algeria': [1540, 1840, 2540, 4526, 5706, 5707, 6986, 7063, 7105, 7233, 8916, 11321, 14529, 14547, 14679, 16685, 22280, 23090, 23949, 24874, 25844, 26445, 27411, 28487, 28572, 29464, 30106, 31300, 31351, 32743, 33029, 33295, 34028, 35173, 35297, 35358, 35517, 36567, 36660, 36709, 37618, 39759, 41257, 41295, 41846, 44462, 46635, 47922, 49027], 'Andorra': [11237, 13745, 24200, 24621, 30215, 39807], 'Angola': [4843, 17795, 30180, 34545, 35524, 37659, 41392], 'Antigua and Barbuda': [26979, 34865], 'Argentina': [88, 195, 209, 218, 411, 470, 875, 963, 1013, 1221, 1301, 1329, 1369, 1663, 1739, 1955, 1972, 2028, 2259, 2448, 2519, 2700, 2729, 2989, 3108, 3224, 3237, 3241, 4119, 4228, 4434, 4464, 4775, 4981, 5460, 5594, 5661, 5684,
# ...

# %%
country_grp.mean(numeric_only=True)
# Out:
#                                         ResponseId    WorkExp  YearsCode  \
# Country
# Afghanistan                           23711.000000  15.000000  13.166667
# Albania                               26708.000000  11.681818  14.272727
# Algeria                               25680.448980   7.342857   8.191489
# Andorra                               23971.833333  19.500000  26.250000
# Angola                                28849.285714   5.333333   5.857143
# ...                                            ...        ...        ...
# Venezuela, Bolivarian Republic of...  23081.765957  13.977778  15.851064
# Viet Nam                              24115.193103   7.491228   9.176471
# Yemen                                 24870.333333   6.266667   5.866667
# Zambia                                26496.923077   6.583333   7.916667
# Zimbabwe                              25038.384615  11.833333  10.307692
#
#                                       TechEndorse_1  TechEndorse_2  \
# Country
# ...

# %%
country_grp['ConvertedCompYearly'].median().loc['Germany']
# Out:
# np.float64(81210.0)

# %%
#multiple aggregrate functions using the agg method
country_grp['ConvertedCompYearly'].agg(['median','mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6121.0   12227.250000
# Albania                                26269.0   47973.583333
# Algeria                                 6472.0   15935.400000
# Andorra                               200125.5  208763.750000
# Angola                                  9578.0  149857.250000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    9000.0   17008.400000
# Viet Nam                                7642.0  189894.192982
# Yemen                                   5545.5   17582.500000
# Zambia                                  1966.5    6594.875000
# Zimbabwe                               17500.0   25662.500000
#
# [177 rows x 2 columns]

# %%
country_grp['ConvertedCompYearly'].agg(['median','mean']).loc['Canada']
# Out:
# median     87550.000000
# mean      100143.382514
# Name: Canada, dtype: float64

# %%
#lets say i want to know how many people in each country knows python
# using filtering approach of a single country
filt = df['Country'] == 'USA'
python_lang = df.columns
df.loc[filt,python_lang]
# Out:
# Empty DataFrame
# ...

# %%
df['Employment']
# Out:
# 0                                                 Employed
# 1                                                 Employed
# 2        Independent contractor, freelancer, or self-em...
# 3                                                 Employed
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 49186                                             Employed
# 49187                                             Employed
# 49188                                             Employed
# 49189    Independent contractor, freelancer, or self-em...
# 49190                                              Student
# Name: Employment, Length: 49191, dtype: str

# %%
df.loc[df['Country']=='United States of America',df.columns == 'Employment']
# Out:
#                                               Employment
# 21                                              Employed
# 22                                              Employed
# 29                                              Employed
# 31                                              Employed
# 33                                              Employed
# ...                                                  ...
# 49125                                           Employed
# 49127                                           Employed
# 49145  Independent contractor, freelancer, or self-em...
# 49157                                           Employed
# 49177                                       Not employed
#
# [7233 rows x 1 columns]

# %%
df.loc[(df['Country']=='United States of America')& (df['Employment'] == 'Employed')]
# Out:
#        ResponseId                                         MainBranch  \
# 21             22  I am not primarily a developer, but I write co...
# 22             23                     I am a developer by profession
# 29             30                     I am a developer by profession
# 31             32                     I am a developer by profession
# 33             34                     I am a developer by profession
# ...           ...                                                ...
# 49123       49124                     I am a developer by profession
# 49124       49125                     I am a developer by profession
# 49125       49126  I work with developers or my work supports dev...
# 49127       49128                     I am a developer by profession
# 49157       49158                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...

# %%
df.loc[df['Country']=='United States of America','Employment']
# Out:
# 21                                                Employed
# 22                                                Employed
# 29                                                Employed
# 31                                                Employed
# 33                                                Employed
#                                ...
# 49125                                             Employed
# 49127                                             Employed
# 49145    Independent contractor, freelancer, or self-em...
# 49157                                             Employed
# 49177                                         Not employed
# Name: Employment, Length: 7233, dtype: str

# %%
schema_df
# Out:
#                          qid  \
# qname
# AIAcc                  QID80
# AIAgentChallenges      QID88
# AIAgentChange          QID83
# AIAgentExtWrite       QID104
# AIAgentExternal        QID92
# AIAgentImpact          QID87
# AIAgentKnowWrite      QID107
# AIAgentKnowledge       QID89
# AIAgentObsWrite       QID103
# AIAgentObserveSecure   QID91
# AIAgentOrchWrite      QID102
# AIAgentOrchestration   QID90
# AIAgent_Uses           QID86
# AIAgents               QID85
# AIComplex              QID81
# AIExplain              QID84
# AIFrustration          QID99
# AIHuman               QID100
# AILearnHow             QID32
# AIModels               QID43
# AIModelsChoice         QID50
# AIModelsHaveEntry      QID68
# AIModelsWantEntry      QID69
# AIOpen                 QID93
# AISelect               QID78
# AISent                 QID79
# AIThreat               QID28
# AITool                 QID82
# Age                     QID4
# AgentUsesGeneral      QID106
# ...

# %%
filtee = df['Country'] == 'India'
df.loc[filtee]
# Out:
#        ResponseId                      MainBranch              Age  \
# 13             14  I am a developer by profession  25-34 years old
# 15             16  I am a developer by profession  18-24 years old
# 46             47  I am a developer by profession  35-44 years old
# 90             91  I am a developer by profession  25-34 years old
# 133           134  I am a developer by profession  25-34 years old
# ...           ...                             ...              ...
# 49132       49133     I code primarily as a hobby  25-34 years old
# 49141       49142  I am a developer by profession  18-24 years old
# 49149       49150  I am a developer by profession  25-34 years old
# 49154       49155  I am a developer by profession  45-54 years old
# 49155       49156  I am a developer by profession  25-34 years old
#
#                                                  EdLevel  \
# 13          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'EdLevel', 'Employment',
#        'EmploymentAddl', 'WorkExp', 'LearnCodeChoose', 'LearnCode',
#        'LearnCodeAI',
#        ...
#        'AIAgentOrchestration', 'AIAgentOrchWrite', 'AIAgentObserveSecure',
#        'AIAgentObsWrite', 'AIAgentExternal', 'AIAgentExtWrite', 'AIHuman',
#        'AIOpen', 'ConvertedCompYearly', 'JobSat'],
#       dtype='str', length=172)

# %%
df.columns== 'Employment'
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
# ...

# %%
df.loc[df['Country'] == 'India',df.columns == 'Employment']
# Out:
#                                               Employment
# 13                                              Employed
# 15                                               Student
# 46                                              Employed
# 90                                              Employed
# 133                                             Employed
# ...                                                  ...
# 49132                                       Not employed
# 49141                                           Employed
# 49149                                           Employed
# 49154  Independent contractor, freelancer, or self-em...
# 49155                                           Employed
#
# [2547 rows x 1 columns]

# %%
df.loc[df['Country'] == 'India','Employment']
# Out:
# 13                                                Employed
# 15                                                 Student
# 46                                                Employed
# 90                                                Employed
# 133                                               Employed
#                                ...
# 49132                                         Not employed
# 49141                                             Employed
# 49149                                             Employed
# 49154    Independent contractor, freelancer, or self-em...
# 49155                                             Employed
# Name: Employment, Length: 2547, dtype: str

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWantToWorkWith'].str.contains('Python').sum()
# Out:
# np.int64(1008)

# %%
df.loc[filt,'Employment']
# Out:
# 13                                                Employed
# 15                                                 Student
# 46                                                Employed
# 90                                                Employed
# 133                                               Employed
#                                ...
# 49132                                         Not employed
# 49141                                             Employed
# 49149                                             Employed
# 49154    Independent contractor, freelancer, or self-em...
# 49155                                             Employed
# Name: Employment, Length: 2547, dtype: str

# %%
df.loc[
    (df['Country'] == 'India') &
    (df['Employment'].str.contains('Student')),
    ['Employment','Age']
]
# Out:
#       Employment              Age
# 15       Student  18-24 years old
# 181      Student  18-24 years old
# 253      Student  18-24 years old
# 433      Student  18-24 years old
# 737      Student  18-24 years old
# ...          ...              ...
# 48344    Student  18-24 years old
# 48441    Student  18-24 years old
# 48972    Student  18-24 years old
# 49037    Student  18-24 years old
# 49089    Student  18-24 years old
#
# [453 rows x 2 columns]

# %%
df['Employment']
# Out:
# 0                                                 Employed
# 1                                                 Employed
# 2        Independent contractor, freelancer, or self-em...
# 3                                                 Employed
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 49186                                             Employed
# 49187                                             Employed
# 49188                                             Employed
# 49189    Independent contractor, freelancer, or self-em...
# 49190                                              Student
# Name: Employment, Length: 49191, dtype: str

# %%
df.loc[:,'Employment']
# Out:
# 0                                                 Employed
# 1                                                 Employed
# 2        Independent contractor, freelancer, or self-em...
# 3                                                 Employed
# 4        Independent contractor, freelancer, or self-em...
#                                ...
# 49186                                             Employed
# 49187                                             Employed
# 49188                                             Employed
# 49189    Independent contractor, freelancer, or self-em...
# 49190                                              Student
# Name: Employment, Length: 49191, dtype: str

# %%
df.loc['Employment' == 'Student']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 df.loc['Employment' == 'Student']
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/indexing.py:1448, in _LocIndexer._getitem_axis(self, key, axis)
#    1445         return self.obj.iloc[tuple(indexer)]
#    1447 # fall thru to straight lookup
# -> 1448 self._validate_key(key, axis)
#    1449 return self._get_label(key, axis=axis)
#
# ...

# %%
df['Employment'] == 'Student'

# %%
df.loc[df['Employment'] == 'Student']
# Out:
#        ResponseId                                         MainBranch  \
# 15             16                     I am a developer by profession
# 64             65                     I am a developer by profession
# 71             72                     I am a developer by profession
# 86             87                     I am a developer by profession
# 98             99  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 49156       49157  I am not primarily a developer, but I write co...
# 49170       49171                              I am learning to code
# 49180       49181                     I am a developer by profession
# 49181       49182                     I am a developer by profession
# 49190       49191  I am not primarily a developer, but I write co...
#
#                    Age                                            EdLevel  \
# ...

# %%
df.loc[filt & df['LanguageWantToWorkWith'].str.contains('Python', na=False)]
# Out:
#        ResponseId                                         MainBranch  \
# 46             47                     I am a developer by profession
# 90             91                     I am a developer by profession
# 342           343                     I am a developer by profession
# 354           355                     I am a developer by profession
# 363           364                     I am a developer by profession
# ...           ...                                                ...
# 48972       48973                     I am a developer by profession
# 48977       48978  I work with developers or my work supports dev...
# 48984       48985                     I am a developer by profession
# 48995       48996                     I am a developer by profession
# 49141       49142                     I am a developer by profession
#
#                    Age                                            EdLevel  \
# ...

# %%
df.loc[df['Country'] == 'India',['Country','Age']]
# Out:
#       Country              Age
# 13      India  25-34 years old
# 15      India  18-24 years old
# 46      India  35-44 years old
# 90      India  25-34 years old
# 133     India  25-34 years old
# ...       ...              ...
# 49132   India  25-34 years old
# 49141   India  18-24 years old
# 49149   India  25-34 years old
# 49154   India  45-54 years old
# 49155   India  25-34 years old
#
# [2547 rows x 2 columns]

# %%
df.loc[df['Country'] == 'India', df.columns == 'Employment']
# Out:
#                                               Employment
# 13                                              Employed
# 15                                               Student
# 46                                              Employed
# 90                                              Employed
# 133                                             Employed
# ...                                                  ...
# 49132                                       Not employed
# 49141                                           Employed
# 49149                                           Employed
# 49154  Independent contractor, freelancer, or self-em...
# 49155                                           Employed
#
# [2547 rows x 1 columns]

# %%
df.loc[(df['Country'] == 'India') & (df['Employment'] == 'Employed')]
# Out:
#        ResponseId                      MainBranch              Age  \
# 13             14  I am a developer by profession  25-34 years old
# 46             47  I am a developer by profession  35-44 years old
# 90             91  I am a developer by profession  25-34 years old
# 133           134  I am a developer by profession  25-34 years old
# 237           238  I am a developer by profession  45-54 years old
# ...           ...                             ...              ...
# 49046       49047  I am a developer by profession  25-34 years old
# 49074       49075  I am a developer by profession  25-34 years old
# 49141       49142  I am a developer by profession  18-24 years old
# 49149       49150  I am a developer by profession  25-34 years old
# 49155       49156  I am a developer by profession  25-34 years old
#
#                                                  EdLevel Employment  \
# 13          Bachelor’s degree (B.A., B.S., B.Eng., etc.)   Employed
# ...

# %%
country_grp['LanguageWantToWorkWith'].str.contains('Python', na=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 country_grp['LanguageWantToWorkWith'].str.contains('Python', na=False)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1115, in GroupBy.__getattr__(self, attr)
#    1112 if attr in self.obj:
#    1113     return self[attr]
# -> 1115 raise AttributeError(
#    1116     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1117 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWantToWorkWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              3
# Albania                                  7
# Algeria                                 14
# Andorra                                  1
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    24
# Viet Nam                                56
# Yemen                                    7
# Zambia                                   3
# Zimbabwe                                 5
# Name: LanguageWantToWorkWith, Length: 177, dtype: int64

# %%
#what percentage
#grab the total number of people/respondents of each country
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                7233
# Germany                                                 3025
# India                                                   2547
# United Kingdom of Great Britain and Northern Ireland    2042
# France                                                  1409
#                                                         ...
# San Marino                                                 1
# Djibouti                                                   1
# Cape Verde                                                 1
# Palau                                                      1
# Guinea                                                     1
# Name: count, Length: 177, dtype: int64

# %%
country_python = country_grp['LanguageWantToWorkWith'].apply(lambda x: x.str.contains('Python').sum())
country_python
# Out:
# Country
# Afghanistan                              3
# Albania                                  7
# Algeria                                 14
# Andorra                                  1
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    24
# Viet Nam                                56
# Yemen                                    7
# Zambia                                   3
# Zimbabwe                                 5
# Name: LanguageWantToWorkWith, Length: 177, dtype: int64

# %%
#combining 2 series
python_df = pd.concat([
    country_respondents,
    country_python
    
], axis='columns', sort=False)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                             7233
# Germany                                              3025
# India                                                2547
# United Kingdom of Great Britain and Northern Ir...   2042
# France                                               1409
# ...                                                   ...
# San Marino                                              1
# Djibouti                                                1
# Cape Verde                                              1
# Palau                                                   1
# Guinea                                                  1
#
#                                                     LanguageWantToWorkWith
# Country
# United States of America                                              2641
# Germany                                                               1064
# ...

# %%
python_df.rename(columns={
    'Country':'NumRespondents',
    'LanguageWantToWorkWith':'NumKnowsPython'
},inplace=True)

# %%
python_df
# Out:
#                                                     count  NumKnowsPython
# Country
# United States of America                             7233            2641
# Germany                                              3025            1064
# India                                                2547            1008
# United Kingdom of Great Britain and Northern Ir...   2042             673
# France                                               1409             531
# ...                                                   ...             ...
# San Marino                                              1               0
# Djibouti                                                1               0
# Cape Verde                                              1               1
# Palau                                                   1               0
# Guinea                                                  1               1
#
# [177 rows x 2 columns]

# %%
#creating a new column
python_df['%KnowsPython'] = (python_df['Country']/python_df['NumKnowsPython'])/100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
python_df.sort_vaues(by='%KnowsPython',ascending=False)

# %%
python_df.loc['Japan']
