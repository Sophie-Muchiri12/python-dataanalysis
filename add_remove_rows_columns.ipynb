# %%
people = {
    "first":["corey","sophie", "cristian"],
    "last":["schafer","muthoni","rodriguez"],
    "email":["corey@gmail.com","muthoni@gmail.com","rodriguez@gmail.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
df['first'] + ' ' + df['last']
# Out:
# 0         corey schafer
# 1        sophie muthoni
# 2    cristian rodriguez
# dtype: str

# %%
#add a new column fullname
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez

# %%
df.drop(columns=['first','last'])
# Out:
#                  email           full_name
# 0      corey@gmail.com       corey schafer
# 1    muthoni@gmail.com      sophie muthoni
# 2  rodriguez@gmail.com  cristian rodriguez

# %%
df['full_name'].str.split(' ')
# Out:
# 0         [corey, schafer]
# 1        [sophie, muthoni]
# 2    [cristian, rodriguez]
# Name: full_name, dtype: object

# %%
#expand argument
df['full_name'].str.split(' ',expand=True)
# Out:
#           0          1
# 0     corey    schafer
# 1    sophie    muthoni
# 2  cristian  rodriguez

# %%
#setting 2 columns to the above columns
df[['first','last']] = df['full_name'].str.split(' ',expand=True)

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez

# %%
#adding and remove columns
#adding a single row
# df.append({
#     'first':'tony'
# },ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 #adding and remove columns
#       2 #adding a single row
# ----> 3 df.append({
#       4     'first':'tony'
#       5 },ignore_index=True)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez

# %%
people = {
    "first":["tony","steve"],
    "last":["stack","rogers"],
    "email":["tony@gmail.com","steve@gmail.com"]
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last            email
# 0   tony   stack   tony@gmail.com
# 1  steve  rogers  steve@gmail.com

# %%
df.append(df2,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.append(df2,ignore_index=True)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez

# %%
df.drop(index=4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.drop(index=4)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
# ...

# %%
df.drop(4,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.drop(4,axis=0)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
# ...

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez

# %%
#adding a new row
df.loc[3] = ['charlie','simpson','charlie@gmail.com','charlie simpson']

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez
# 3   charlie    simpson    charlie@gmail.com     charlie simpson

# %%
df.drop(3,axis=0)
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez

# %%
df
# Out:
#       first       last                email           full_name
# 0     corey    schafer      corey@gmail.com       corey schafer
# 1    sophie    muthoni    muthoni@gmail.com      sophie muthoni
# 2  cristian  rodriguez  rodriguez@gmail.com  cristian rodriguez
# 3   charlie    simpson    charlie@gmail.com     charlie simpson

# %%
#drop using a condition
df.drop(df['last']== 'simpson')
