# %%
people = {
    "first":["corey","sophie", "cristian"],
    "last":["schafer","muthoni","rodriguez"],
    "email":["corey@gmail.com","muthoni@gmail.com","rodriguez@gmail.com"]
}

# %%
import pandas as pd

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
#looking at columns

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='str')

# %%
# modifying column name
df.columns = ['first_name','last_name','email']

# %%
df
# Out:
#   first_name  last_name                email
# 0      corey    schafer      corey@gmail.com
# 1     sophie    muthoni    muthoni@gmail.com
# 2   cristian  rodriguez  rodriguez@gmail.com

# %%
#list comprehensions
df.columns = [x.upper() for x in df.columns]

# %%
df
# Out:
#   FIRST_NAME  LAST_NAME                EMAIL
# 0      corey    schafer      corey@gmail.com
# 1     sophie    muthoni    muthoni@gmail.com
# 2   cristian  rodriguez  rodriguez@gmail.com

# %%
df.columns = ['first name','last name','email']

# %%
df
# Out:
#   first name  last name                email
# 0      corey    schafer      corey@gmail.com
# 1     sophie    muthoni    muthoni@gmail.com
# 2   cristian  rodriguez  rodriguez@gmail.com

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df
# Out:
#   first_name  last_name                email
# 0      corey    schafer      corey@gmail.com
# 1     sophie    muthoni    muthoni@gmail.com
# 2   cristian  rodriguez  rodriguez@gmail.com

# %%
#rename method and pass a dictionary
df.rename(columns={
    'first_name':'first',
    'last_name':'last'

},inplace=True)

# %%
df
# Out:
#       first       last                email
# 0     corey    schafer      corey@gmail.com
# 1    sophie    muthoni    muthoni@gmail.com
# 2  cristian  rodriguez  rodriguez@gmail.com

# %%
#updating a single value
df.loc[2]
# Out:
# first               cristian
# last               rodriguez
# email    rodriguez@gmail.com
# Name: 2, dtype: str

# %%
#updating a single value
df.loc[2] = ['john','smith','johnsmith@gmail.com']

# %%
df
# Out:
#     first     last                email
# 0   corey  schafer      corey@gmail.com
# 1  sophie  muthoni    muthoni@gmail.com
# 2    john    smith  johnsmith@gmail.com

# %%
#updating a multiple value for a single row
df.loc[2,['last','email']] = ['Doe','johndoe@gmail.com']

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john      Doe  johndoe@gmail.com

# %%
df.loc[2,'last'] = 'Smith'

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john    Smith  johndoe@gmail.com

# %%
df.at[2,'last']
# Out:
# 'Smith'

# %%
df.at[2,'last'] = 'Doe'

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john      Doe  johndoe@gmail.com

# %%
#using a filter
filt = (df['email'] == 'johndoe@gmail.com')

# %%
df[filt]
# Out:
#   first last              email
# 2  john  Doe  johndoe@gmail.com

# %%
df[filt]['last']
# Out:
# 2    Doe
# Name: last, dtype: str

# %%
# df[filt]['last'] = 'smith' #set in a temporary object get an error

# %%
df.loc[filt, 'last'] = 'Smith'

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john    Smith  johndoe@gmail.com

# %%
#updating multiple rows of data setting the column to lower case value of itself
df['email'].str.upper() #this assigns lower case but hasnt really implemented
# Out:
# 0      COREY@GMAIL.COM
# 1    MUTHONI@GMAIL.COM
# 2    JOHNDOE@GMAIL.COM
# Name: email, dtype: str

# %%
df['email'] = df['email'].str.upper()

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    COREY@GMAIL.COM
# 1  sophie  muthoni  MUTHONI@GMAIL.COM
# 2    john    Smith  JOHNDOE@GMAIL.COM

# %%
#apply - calling a function on our values can work on either a dataframe or a series object

#map
#apply map

# %%
#apply on series: applies a function on every value on our series
df['email'].apply(len)
# Out:
# 0    15
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
#update values using apply
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email) #this doesnt really change the row values
# Out:
# 0      COREY@GMAIL.COM
# 1    MUTHONI@GMAIL.COM
# 2    JOHNDOE@GMAIL.COM
# Name: email, dtype: str

# %%
df['email'] = df['email'].apply(update_email) #this changes the row values

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    COREY@GMAIL.COM
# 1  sophie  muthoni  MUTHONI@GMAIL.COM
# 2    john    Smith  JOHNDOE@GMAIL.COM

# %%
#using lambda function (dont actually have a name)
df['email'] = df['email'].apply(lambda x:x.lower())

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john    Smith  johndoe@gmail.com

# %%
#apply on dataframes runs the function on each column/series in it
df.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
len(df['email']) #manually check the length of a series
# Out:
# 3

# %%
#min method
df.apply(pd.Series.min)
# Out:
# first              corey
# last               Smith
# email    corey@gmail.com
# dtype: str

# %%
df.apply(lambda x:x.min())
# Out:
# first              corey
# last               Smith
# email    corey@gmail.com
# dtype: str

# %%
#what about applying a function to every value to a dataframe
#applymap - being disregarded
df.map(len)
# Out:
#    first  last  email
# 0      5     7     15
# 1      6     7     17
# 2      4     5     17

# %%
df.map(str.lower)
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john    smith  johndoe@gmail.com

# %%
df['first'].map({
    'corey':'chrisss',
    'sophie':'soni'
})
# Out:
# 0    chrisss
# 1       soni
# 2        NaN
# Name: first, dtype: str

# %%
df['first'].replace({
    'corey':'chrisss',
    'sophie':'soni'
})
# Out:
# 0    chrisss
# 1       soni
# 2       john
# Name: first, dtype: str

# %%
df
# Out:
#     first     last              email
# 0   corey  schafer    corey@gmail.com
# 1  sophie  muthoni  muthoni@gmail.com
# 2    john    Smith  johndoe@gmail.com

# %%
#now we apply to the actual column
df['first'] = df['first'].replace({
    'corey':'chrisss',
    'sophie':'soni'
})

# %%
df
# Out:
#      first     last              email
# 0  chrisss  schafer    corey@gmail.com
# 1     soni  muthoni  muthoni@gmail.com
# 2     john    Smith  johndoe@gmail.com

# %%
df.drop(index=4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.drop(index=4)
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/frame.py:6288, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6284                 weight  250.0   150.0
#    6285         falcon  speed   320.0   250.0
#    6286                 weight  1.0     0.8
#    6287         """
# -> 6288         return super().drop(
#    6289             labels=labels,
#    6290             axis=axis,
#    6291             index=index,
#
# File ~/Python/dataanalysis/panda/venv/lib/python3.13/site-packages/pandas/core/generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
# ...
